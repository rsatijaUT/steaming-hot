# %%
from bs4 import BeautifulSoup
#from urllib.request import urlopen
import pandas as pd
import numpy as np
import requests

#For plotting
import matplotlib.pyplot as plt

# %%
# We grab data from the stored csv files:
real_id = pd.read_csv('real_id.csv')
fake_id = pd.read_csv('fake_id.csv')
avg_player = pd.read_csv('avg_player.csv')
gain = pd.read_csv('gain.csv')
p_gain = pd.read_csv('p_gain.csv')
peak_player = pd.read_csv('peak_player.csv')

# %%
avg_player.head()
# Out:
#    real_id                       name  Last 30 Days  April 2021  March 2021  \
# 0       10             Counter-Strike      11721.23    12426.28    12311.34
# 1       20      Team Fortress Classic         56.94       57.63       61.19
# 2       30              Day of Defeat        101.50      103.37      105.42
# 3       40         Deathmatch Classic          2.83        2.95        4.42
# 4       50  Half-Life: Opposing Force         84.70       83.77       89.22
#
#    February 2021  January 2021  December 2020  November 2020  October 2020  \
# 0       12091.33      13094.31       12239.53       11278.70      10320.58
# 1          68.31         79.08          74.00          70.45         69.89
# 2         112.93        117.04         112.77         109.85        104.98
# 3           4.90          4.41           4.78           6.74          7.45
# 4         105.72        128.28         111.27          93.25         78.46
#
#    ...  April 2013  March 2013  February 2013  January 2013  December 2012  \
# 0  ...    21204.46    24139.15       28378.42      34814.47       31996.07
# 1  ...       73.58       77.73          82.32         89.00          87.79
# 2  ...      217.90      297.55         318.41        319.62         318.08
# 3  ...        4.64        5.78           7.11          6.91           6.72
# 4  ...       43.04       39.92          43.15         50.20          47.06
#
#    November 2012  October 2012  September 2012  August 2012  July 2012
# 0       29669.97      28836.29        29432.56     33095.80   34139.20
# 1          78.58         77.51           83.83        93.03      98.17
# 2         303.99        297.00          289.59       304.47     331.84
# 3           6.18          5.56            6.26         7.41       8.61
# 4          38.63         41.30           56.26        55.77      79.06
#
# [5 rows x 109 columns]

# %%
#Remember to remove the first 2 columns when plotting.

plt.figure(figsize=(12,12))

plt.plot(avg_player.iloc[1][2:])
plt.plot(avg_player.iloc[4][2:])

plt.show()
